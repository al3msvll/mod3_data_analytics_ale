# %%
pip install pandas # Installing the pandas library
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 3.3. Ejercicios de Pandas: Análisis de Datos Exploratorio (EDA - Exploratory Data Analysis)

# %% [markdown]
# #Index
#
# - [1](#1) ## 1.Abrid el fichero de rating-and-performance con el método que sea más correcto.
#
# - [2](#2) ## 2.Mostrad las 10 últimas filas.
#
# - [3](#3) ## 3.Mostrad 5 filas aleatorias del DataFrame.
#
# - [4](#4) ## 4.¿Cuántas filas y columnas tenemos en el DataFrame?
#
# - [5](#5)   ## 5.¿Cuáles son los nombres de las columnas del DataFrame?
#
# - [6](#6)   ## 6.Seleccionad solo las columnas de tipo categórico del DataFrame. Después, mostrad los valores únicos y sus frecuencias para cada una de las columnas seleccionadas.
#
# - [7](#7)   ## 7.En el DataFrame tenemos dos columnas que parece que nos dan la misma información "title" y "title_orig". Eliminad "title".
#
# - [8](#8)   ## 8.¿En que columnas tenemos valores nulos? Utilizad el método que más os guste.
#
# - [9](#9)   ## 9.¿Tenemos valores duplicados en el DataFrame?

# %% [markdown]
# *EJERCICIOS DE PANDAS: ANALISIS DATOS EXPLORATIVO (EDA_EXPLORATORY DATA ANALYSIS)*

# %% [markdown]
# ## 1

# %%
import pandas as pd # Importing the pandas library

# %%
df = pd.read_csv('/Users/alejandramartinsevilla/Desktop/ratingandperformance.csv')

print(df.head()) # 1. Display the first 5 rows of the DataFrame
# Out:
#    index                                              title  \
# 0      0  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      1  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2  2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      3  Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      4  Femmes Shorts d'été à lacets taille élastique ...
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2  2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4  Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  ...  \
# 0            EUR         100               0    3.76            54  ...
# ...

# %% [markdown]
# ## 2

# %%
df.tail(10) # 2.Display the last 10 rows of the DataFrame
# Out:
#       index                                         title_orig  price  \
# 1563   1563  ZANZEA Women Summer Polka Dot Kaftan Beach Clu...  15.00
# 1564   1564  2018 Women fashion Summer Lace Patchwork Tank ...   5.91
# 1565   1565  New Summer Fashion Trousers Women Leggings Rip...   3.00
# 1566   1566  Womens Short Sleeve Baggy Summer Beach Midi Dr...  11.00
# 1567   1567  Sleeveless Solid Color Women Jumpsuit Ladies S...   8.00
# 1568   1568  New Fashion Women Bohemia Dandelion Print Tee ...   6.00
# 1569   1569  10 Color Women Summer Shorts Lace Up Elastic W...   2.00
# 1570   1570  New Men Siwmwear Beach-Shorts Men Summer Quick...   5.00
# 1571   1571  Fashion Women Summer Sleeveless Dresses V Neck...  13.00
# 1572   1572  Fashion Women Yoga Pants Slim Fit Fitness Runn...   7.00
#
#       retail_price currency_buyer  units_sold  uses_ad_boosts  rating  \
# 1563            92            EUR         100               0    3.51
# ...

# %% [markdown]
# ## 3

# %%
df.sample(n=5) # 3. Randomly sample 5 rows from the DataFrame
# Out:
#       index                                              title  \
# 1151   1151  Womens Summer Bohemia Floral Beach Dress Ladie...
# 934     934  Chemisiers sans manches d'été pour femmes Casu...
# 184     184  2018 Summer New Women Jupes Longues Jupes Soli...
# 1023   1023  5 Couleur Nouvelle Arrivée Femmes De Mode Sexy...
# 1550   1550  8 Couleurs Femmes Off The Shoulder Crop Cops S...
#
#                                              title_orig  price  retail_price  \
# 1151  Womens Summer Bohemia Floral Beach Dress Ladie...   15.0           102
# 934   Women's Summer Sleeveless Blouses Casual Sling...    6.0             6
# 184   2018 Summer New Women Long Skirts Solid Sexy S...    9.0            36
# 1023  5 Color New Arrival Women's Fashion Sexy Elega...    8.0             9
# 1550  8 Colors Women's Off The Shoulder Crop Tops Ca...    3.0             3
#
#      currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  ...  \
# ...

# %% [markdown]
# ## 4

# %%
#¿Cuántas filas y columnas tenemos en el DataFrame?
print(df.shape) # 4. Display the number of rows and columns in the DataFrame
# Out:
# (1573, 44)

# %%
print((df.shape[0])*(df.shape[1])) # 4.Display the number of elements in the DataFrame
# Out:
# 69212

# %% [markdown]
# ## 5

# %%
#5. ¿Cuáles son los nombres de las columnas del DataFrame?
print(df.columns)
# Out:
# Index(['index', 'title', 'title_orig', 'price', 'retail_price',
#        'currency_buyer', 'units_sold', 'uses_ad_boosts', 'rating',
#        'rating_count', 'rating_five_count', 'rating_four_count',
#        'rating_three_count', 'rating_two_count', 'rating_one_count',
#        'badges_count', 'badge_local_product', 'badge_product_quality',
#        'badge_fast_shipping', 'tags', 'product_color',
#        'product_variation_size_id', 'product_variation_inventory',
#        'shipping_option_name', 'shipping_option_price', 'shipping_is_express',
#        'countries_shipped_to', 'inventory_total', 'has_urgency_banner',
#        'urgency_text', 'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %% [markdown]
# ## 6

# %%
df.describe(include ='object') # 6. Display the summary statistics of the DataFrame for object data types
# Out:
#                                                     title  \
# count                                                1573
# unique                                               1201
# top     Nouvelle mode d'été femmes robe décontractée c...
# freq                                                   24
#
#                                                title_orig currency_buyer  \
# count                                                1573           1573
# unique                                               1203              1
# top     New Fashion Summer Women Casual Dress Round Ne...            EUR
# freq                                                   24           1573
#
#                                                      tags product_color  \
# count                                                1573          1532
# unique                                               1230           101
# top     Summer,Fashion,Necks,Skirts,Dress,Loose,Women'...         black
# ...

# %%
for col in df.columns: # 7. Display the number of unique values in each column
    uniques = df[col].nunique() # Display the number of unique values in each column
    if uniques < 10: # Display the number of unique values in each column
        print (f"column {col}: {uniques} unique values")
# Out:
# column currency_buyer: 1 unique values
# column uses_ad_boosts: 2 unique values
# column badges_count: 4 unique values
# column badge_local_product: 2 unique values
# column badge_product_quality: 2 unique values
# column badge_fast_shipping: 2 unique values
# column shipping_option_price: 8 unique values
# column shipping_is_express: 2 unique values
# column has_urgency_banner: 1 unique values
# column urgency_text: 2 unique values
# column origin_country: 6 unique values
# column merchant_has_profile_picture: 2 unique values
# column theme: 1 unique values
# column crawl_month: 1 unique values

# %% [markdown]
# ## 8

# %%
df.info()
# 8. Display the data types of each column
print(df.dtypes) # Display the data types of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 44 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   index                         1573 non-null   int64
#  1   title                         1573 non-null   object
#  2   title_orig                    1573 non-null   object
#  3   price                         1573 non-null   float64
#  4   retail_price                  1573 non-null   int64
#  5   currency_buyer                1573 non-null   object
#  6   units_sold                    1573 non-null   int64
#  7   uses_ad_boosts                1573 non-null   int64
#  8   rating                        1573 non-null   float64
#  9   rating_count                  1573 non-null   int64
#  10  rating_five_count             1528 non-null   float64
#  11  rating_four_count             1528 non-null   float64
# ...

# %%
columnas_categoricas = df.select_dtypes(include='object') # 6. Display the data types of each column that are object type

# %%
display(columnas_categoricas.head(3))
df.head(2)  # 6. Display the DataFrame with only object type columns
# Out:
#                                                title  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2  2020 Nouvelle Arrivée Femmes Printemps et Été ...
#
#                                           title_orig currency_buyer  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...            EUR
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress            EUR
# 2  2020 New Arrival Women Spring and Summer Beach...            EUR
#
#                                                 tags product_color  \
# 0  Summer,Fashion,womenunderwearsuit,printedpajam...         white
# 1  Mini,womens dresses,Summer,Patchwork,fashion d...         green
# 2  Summer,cardigan,women beachwear,chiffon,Sexy w...  leopardprint
#
#   product_variation_size_id shipping_option_name        urgency_text  \
# 0                         M   Livraison standard  Quantité limitée !
# ...

# %%
# 6. Display the number of unique values in each column that are object type
for col in columnas_categoricas.columns:
    uniques = columnas_categoricas[col].nunique()
    if uniques < 10:
        print (f"column {col}: {uniques} unique values")
df.describe(include='object').T # Display the summary statistics of the DataFrame for
# Out:
# column currency_buyer: 1 unique values
# column urgency_text: 2 unique values
# column origin_country: 6 unique values
# column theme: 1 unique values
# column crawl_month: 1 unique values
#                           count unique  \
# title                      1573   1201
# title_orig                 1573   1203
# currency_buyer             1573      1
# tags                       1573   1230
# product_color              1532    101
# product_variation_size_id  1559    106
# shipping_option_name       1573     15
# urgency_text                473      2
# origin_country             1556      6
# merchant_title             1573    958
# merchant_name              1569    957
# merchant_info_subtitle     1572   1058
# merchant_id                1573    958
# merchant_profile_picture    226    125
# product_url                1573   1341
# product_picture            1573   1341
# product_id                 1573   1341
# theme                      1573      1
# ...

# %%
df.describe(include='object').T # Display the summary statistics of the DataFrame for object data types, transposed for better readability
df.describe(include='object').T.sort_values(by='unique', ascending=False) # Display the
# Out:
#                           count unique  \
# product_id                 1573   1341
# product_picture            1573   1341
# product_url                1573   1341
# tags                       1573   1230
# title_orig                 1573   1203
# title                      1573   1201
# merchant_info_subtitle     1572   1058
# merchant_id                1573    958
# merchant_title             1573    958
# merchant_name              1569    957
# merchant_profile_picture    226    125
# product_variation_size_id  1559    106
# product_color              1532    101
# shipping_option_name       1573     15
# origin_country             1556      6
# urgency_text                473      2
# currency_buyer             1573      1
# theme                      1573      1
# crawl_month                1573      1
#
#                                                                          top  \
# product_id                                          5e16cb87e6dd7c03be24b28a
# ...

# %% [markdown]
# ## 7

# %%
# 7. En el DataFrame tenemos dos columnas que parece que nos dan la misma información "title" y "title_orig". Eliminad "title".
df = df.drop(columns=['title'])

display(df.head(2)) # Display the DataFrame after dropping the 'title' column
# Out:
#    index                                         title_orig  price  \
# 0      0  2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0
# 1      1   Women's Casual Summer Sleeveless Sexy Mini Dress    8.0
#
#    retail_price currency_buyer  units_sold  uses_ad_boosts  rating  \
# 0            14            EUR         100               0    3.76
# 1            22            EUR       20000               1    3.45
#
#    rating_count  rating_five_count  ...  merchant_rating_count  \
# 0            54               26.0  ...                    568
# 1          6135             2269.0  ...                  17752
#
#    merchant_rating               merchant_id  merchant_has_profile_picture  \
# 0         4.128521  595097d6a26f6e070cb878d1                             0
# 1         3.899673  56458aa03a698c35c9050988                             0
#
#    merchant_profile_picture                                      product_url  \
# ...

# %% [markdown]
# ## 8

# %%
#8.¿En que columnas tenemos valores nulos? Utilizad el método que más os guste.
col_vnulos = print(df.isnull().sum())
# Out:
# index                              0
# title_orig                         0
# price                              0
# retail_price                       0
# currency_buyer                     0
# units_sold                         0
# uses_ad_boosts                     0
# rating                             0
# rating_count                       0
# rating_five_count                 45
# rating_four_count                 45
# rating_three_count                45
# rating_two_count                  45
# rating_one_count                  45
# badges_count                       0
# badge_local_product                0
# badge_product_quality              0
# badge_fast_shipping                0
# tags                               0
# product_color                     41
# product_variation_size_id         14
# product_variation_inventory        0
# shipping_option_name               0
# shipping_option_price              0
# shipping_is_express                0
# ...

# %%
print("Column", {col_vnulos}, "has null values:", df[col_vnulos].isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 1
# ...

# %%
 #9 ¿Tenemos valores duplicados en el DataFrame?
df.duplicated().sum() == 0
# Out:
# True
